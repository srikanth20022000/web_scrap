# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\srika\Downloads\college_data.csv")
data
# Out:
#                                                  names  \
# 0            AAA College of Engineering and Technology
# 1                      Aadishwar College of Technology
# 2    AAERT and SSB Faculty of Architecture, Sarvaja...
# 3                        Aakar Academy of Architecture
# 4        Aalim Muhammed Salegh Academy of Architecture
# ..                                                 ...
# 495                          Arni School of Technology
# 496                                    Arni University
# 497      ARPIT Institute of Engineering and Technology
# 498                   Arrdekta Institute of Technology
# 499                         ARS College of Engineering
#
#                                   Top_course          location public/private  \
# 0        BE Computer Science and Engineering      Virudhunagar        Private
# 1              B.Tech Electrical Engineering     Bhoyan Rathod        Private
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   names           500 non-null    object
#  1   Top_course      500 non-null    object
#  2   location        500 non-null    object
#  3   public/private  500 non-null    object
#  4   rating/5        254 non-null    float64
#  5   fee_structure   131 non-null    float64
#  6   entrance_text   178 non-null    object
#  7   other_course    267 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 31.4+ KB

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [names, Top_course, location, public/private, rating/5, fee_structure, entrance_text, other_course]
# Index: []

# %%
#data.fillna(0.0,inplace=True)

# %%
data
# Out:
#                                                  names  \
# 0            AAA College of Engineering and Technology
# 1                      Aadishwar College of Technology
# 2    AAERT and SSB Faculty of Architecture, Sarvaja...
# 3                        Aakar Academy of Architecture
# 4        Aalim Muhammed Salegh Academy of Architecture
# ..                                                 ...
# 495                          Arni School of Technology
# 496                                    Arni University
# 497      ARPIT Institute of Engineering and Technology
# 498                   Arrdekta Institute of Technology
# 499                         ARS College of Engineering
#
#                                   Top_course          location public/private  \
# 0        BE Computer Science and Engineering      Virudhunagar        Private
# 1              B.Tech Electrical Engineering     Bhoyan Rathod        Private
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   names           500 non-null    object
#  1   Top_course      500 non-null    object
#  2   location        500 non-null    object
#  3   public/private  500 non-null    object
#  4   rating/5        254 non-null    float64
#  5   fee_structure   131 non-null    float64
#  6   entrance_text   178 non-null    object
#  7   other_course    267 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 31.4+ KB

# %%
data=data.infer_objects()
data
# Out:
#                                                  names  \
# 0            AAA College of Engineering and Technology
# 1                      Aadishwar College of Technology
# 2    AAERT and SSB Faculty of Architecture, Sarvaja...
# 3                        Aakar Academy of Architecture
# 4        Aalim Muhammed Salegh Academy of Architecture
# ..                                                 ...
# 495                          Arni School of Technology
# 496                                    Arni University
# 497      ARPIT Institute of Engineering and Technology
# 498                   Arrdekta Institute of Technology
# 499                         ARS College of Engineering
#
#                                   Top_course          location public/private  \
# 0        BE Computer Science and Engineering      Virudhunagar        Private
# 1              B.Tech Electrical Engineering     Bhoyan Rathod        Private
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   names           500 non-null    object
#  1   Top_course      500 non-null    object
#  2   location        500 non-null    object
#  3   public/private  500 non-null    object
#  4   rating/5        254 non-null    float64
#  5   fee_structure   131 non-null    float64
#  6   entrance_text   178 non-null    object
#  7   other_course    267 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 31.4+ KB

# %%
data["rating/5"].mean()
# Out:
# 3.9539370078740155

# %%
data["rating/5"].mode()
# Out:
# 0    4.0
# Name: rating/5, dtype: float64

# %%
data["rating/5"].median()
# Out:
# 4.1

# %%
data["fee_structure"].mean()
# Out:
# 5.072671755725191

# %%
data["fee_structure"].median()
# Out:
# 3.7

# %%
data["fee_structure"].mode()
# Out:
# 0     1.0
# 1     2.8
# 2     3.6
# 3    24.0
# Name: fee_structure, dtype: float64

# %%
data["other_course"].mean()
# Out:
# 6.98876404494382

# %%
data["other_course"].median()
# Out:
# 6.0

# %%
data["other_course"].mode()
# Out:
# 0    5.0
# Name: other_course, dtype: float64

# %%
data.fillna(value={
    "names":"no_name",
    "Top_course" :"no_course",
    "location":"no_loc",
    "public/private":"no_owner",
    "rating/5":data["rating/5"].mean(),
    "fee_structure":data["fee_structure"].median(),
    "entrance_text":data["entrance_text"].mode()[0],
    "other_course":data["other_course"].median()
   
},
            inplace=True)

# %%
data
# Out:
#                                                  names  \
# 0            AAA College of Engineering and Technology
# 1                      Aadishwar College of Technology
# 2    AAERT and SSB Faculty of Architecture, Sarvaja...
# 3                        Aakar Academy of Architecture
# 4        Aalim Muhammed Salegh Academy of Architecture
# ..                                                 ...
# 495                          Arni School of Technology
# 496                                    Arni University
# 497      ARPIT Institute of Engineering and Technology
# 498                   Arrdekta Institute of Technology
# 499                         ARS College of Engineering
#
#                                   Top_course          location public/private  \
# 0        BE Computer Science and Engineering      Virudhunagar        Private
# 1              B.Tech Electrical Engineering     Bhoyan Rathod        Private
# ...

# %%
data.to_csv("final_data.csv",index=False)
