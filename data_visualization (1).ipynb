# %%
import pandas as pd

# %%
mat=pd.read_csv(r"C:\Users\srika\Downloads\college_data.csv")
mat
# Out:
#                                                  names  \
# 0            AAA College of Engineering and Technology
# 1                      Aadishwar College of Technology
# 2    AAERT and SSB Faculty of Architecture, Sarvaja...
# 3                        Aakar Academy of Architecture
# 4        Aalim Muhammed Salegh Academy of Architecture
# ..                                                 ...
# 495                          Arni School of Technology
# 496                                    Arni University
# 497      ARPIT Institute of Engineering and Technology
# 498                   Arrdekta Institute of Technology
# 499                         ARS College of Engineering
#
#                                   Top_course          location public/private  \
# 0        BE Computer Science and Engineering      Virudhunagar        Private
# 1              B.Tech Electrical Engineering     Bhoyan Rathod        Private
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # univarient analysis

# %% [markdown]
# # numerical

# %%
# histogram , box plot
# fee structure
plt.figure(figsize=(3,2), dpi=250)
plt.hist(mat['fee_structure'], bins=20, edgecolor="black",)
plt.grid(linestyle="--", color="red", linewidth=0.4)
plt.xlabel('fee')
plt.ylabel('Count/colleges')
plt.title("based on fees no of colleges")
plt.show()

# %%
#rating
plt.figure(figsize=(3,2), dpi=250)
plt.hist(mat['rating/5'], bins=20, edgecolor="black",)
plt.grid(linestyle="--", color="red", linewidth=0.4)
plt.xlabel('rating')
plt.ylabel('colleges/count')
plt.title("based on rating no of colleges")
plt.show()

# %%
sns.boxplot(data=mat, y='fee_structure', width=0.7)
plt.axhline(5.8, linestyle="--", color="red")
plt.title("outliers in fee structure")
plt.show()

# %%
plt.title("outliers in other courses")
sns.boxplot(data=mat, y='other_course', width=0.7)
plt.axhline(5.8, linestyle="--", color="red")
plt.show()

# %%
#courses
plt.figure(figsize=(3,2), dpi=250)
plt.hist(mat['other_course'], bins=20, edgecolor="black",)
plt.grid(linestyle="--", color="red", linewidth=0.4)
plt.xlabel('courses')
plt.ylabel('colleges')
plt.title("colleges having other courses")
plt.show()

# %% [markdown]
# # category

# %%
sns.countplot(data = mat, y="entrance_text")
plt.title("entrance test to get admission in engineering")
plt.show()

# %%
# category
from wordcloud import WordCloud

# %%
text = mat["entrance_text"].str.cat(sep=" ")
text
# Out:
# 'JEE JEE JEE NATA JEE JEE JEE JEE JEE TS JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE TS JEE UPCET JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEXPO UPCET JEE JEE AMET JEE JEE JEE JEE JEE JEE UPCET JEE JEE JEE JEE JEE JEE COMEDK JEE JEE AP JEE CUET JEE JEE JEE JEE JEXPO JEE JEE JEE JEE JEE KCET JEE JEE UPCET JEE JEE JEE JEE JEE JEE JEE JEE JEE TS JEE JEE JEE JEE JEE AP JEE JEE JEE JEE JEECUP JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE UPCET COMEDK JEE JEE JEE JEE JEE KEAM JEE JEE JEE JEE COMEDK AP JEE AP JEE JEE JEE JEE JEE JEE JEE AP JEE JEE JEE JEE GUJCET JEE GUJCET JEECUP MHT JEE JEE JEE JEE JEE CIPET JEE JEE JEE JEE JEE JEE JEECUP JEE JEE AP JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE NATA JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE KEAM JEE GUJCET JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE KCET JEE JEE JEE JEE JEE JEE JEE JEE COMEDK JEE JEE JEE JEE JEE JEE JEE AP JEE JEE JEE JEE KCET JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE JEE AP J
# ...

# %%
text =mat["entrance_text"].str.cat(sep=" ")
wordcloud = WordCloud(max_font_size=80, max_words=50, colormap='flag', width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10,10))
plt.plot()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("main exam in engineering college")
plt.show()

# %% [markdown]
# # bi varient analysis

# %% [markdown]
# # numeric and category

# %%
plt.title("pub/pri based fee structure ")
sns.boxplot(data=mat, x='public/private', y='fee_structure', width=0.9)
plt.show()

# %% [markdown]
# # numeric vs numeric

# %%
# numeric vs numeric 
plt.figure(figsize=(5,3), dpi=150)
plt.title("rating and fee structure")
sns.scatterplot(data = mat, x = 'rating/5', y = 'other_course', marker = "*", color = "blue" )
plt.show()

# %%
# numeric vs numeric 
plt.figure(figsize=(5,3), dpi=150)
plt.title("rating and fee structure")
sns.scatterplot(data = mat, x = 'rating/5', y = 'fee_structure', marker = "*", color = "blue" )
plt.show()

# %% [markdown]
# # category vs category

# %%
sns.catplot(data=mat,x="public/private",y="entrance_text")
# Out:
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # multivariate analysis

# %%
# pair plot
import warnings

sns.pairplot(mat)  # Automatically plots scatterplots for all combinations
plt.show()
# Out:
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Create a pair plot with hue='category'
sns.pairplot(mat, hue='public/private', markers=['o', 's'], palette='Set1')
plt.show()
# Out:
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(mat, hue='entrance_text', markers=['o', '*'], palette='Set1')
plt.show()
# Out:
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1609: UserWarning:
# ...

# %%
# Create a pair plot with hue='category'
sns.pairplot(mat, hue='Top_course', markers=['o', '*'], palette='Set1')
plt.show()
# Out:
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\srika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1609: UserWarning:
# ...
